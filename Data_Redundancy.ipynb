# %%
import pandas as pd

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df.loc[df.duplicated(),:]
# Out:
#     PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 12            6       0.0       3         Moran, Mr. James  male   NaN      0
# 28            6       0.0       3         Moran, Mr. James  male   NaN      0
# 39            6       0.0       3         Moran, Mr. James  male   NaN      0
# 55            7       0.0       1  McCarthy, Mr. Timothy J  male  54.0      0
# 67            7       0.0       1  McCarthy, Mr. Timothy J  male  54.0      0
#
#     Parch  Ticket     Fare Cabin Embarked
# 12      0  330877   8.4583   NaN        Q
# 28      0  330877   8.4583   NaN        Q
# 39      0  330877   8.4583   NaN        Q
# 55      0   17463  51.8625   E46        S
# 67      0   17463  51.8625   E46        S

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 891          887       0.0       2
# 892          888       1.0       1
# 893          889       0.0       3
# 894          890       1.0       1
# 895          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
