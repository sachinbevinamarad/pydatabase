# %% [markdown]
# import  requird libraries and read titanic dataset

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("dataset/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe() # the describe function will return the columns with numerical data using some aggregation function
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  887.000000  891.000000  713.000000  891.000000
# mean    446.000000    0.382187    2.308642   29.704306    0.523008
# std     257.353842    0.486196    0.836071   14.536033    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  888.000000
# mean     0.381594   32.282530
# std      0.806057   49.758986
# min      0.000000    0.000000
# 25%      0.000000    7.917700
# 50%      0.000000   14.456250
# 75%      0.000000   31.068750
# max      6.000000  512.329200

# %%
df.info()  # print a concise summary of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     887 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         888 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
df.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.index #it will return the start,stop.jump indexing of the given datafram
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns # 'columns' will return all the columns in the dataframe
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head() # head() will give the upper 5 lines of the dataframe
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female   NaN      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282      NaN   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female   NaN      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.isnull()  # if the value is null then it writes 'True' else 'False'
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False      True   False  False  False  False  False  False   False
# 2          False      True   False  False  False   True  False  False   False
# 3          False      True   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         4
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             3
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[['Age']].isnull().sum()
# Out:
# Age    178
# dtype: int64

# %%
df[['Age','Cabin']].isnull().sum()
# Out:
# Age      178
# Cabin    687
# dtype: int64

# %%
df1 = df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1) # it is  used to delete the columns
df1
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         NaN       1  female  38.0      1      0  71.2833        C
# 2         NaN       3  female   NaN      0      0      NaN        S
# 3         NaN       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female   NaN      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  887.000000  891.000000  713.000000  891.000000  891.000000  888.000000
# mean     0.382187    2.308642   29.704306    0.523008    0.381594   32.282530
# std      0.486196    0.836071   14.536033    1.102743    0.806057   49.758986
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.917700
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.456250
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.068750
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.isnull().sum()
# Out:
# Survived      4
# Pclass        0
# Sex           0
# Age         178
# SibSp         0
# Parch         0
# Fare          3
# Embarked      2
# dtype: int64

# %%
df2 = df1.fillna(method="ffill")
df2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         0.0       1  female  38.0      1      0  71.2833        C
# 2         0.0       3  female  38.0      0      0  71.2833        S
# 3         0.0       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female  19.0      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df2.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
survived_count= df2.groupby('Survived')['Survived'].count() #This can beused to group large amounts of data and compute operations on thesegroups.
survived_count
# Out:
# Survived
# 0.0    552
# 1.0    339
# Name: Survived, dtype: int64

# %%
pclass_count = df2.groupby('Pclass')['Pclass'].count()
pclass_count
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
sex_count = df2.groupby('Sex')['Sex'].count()
sex_count
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
embarked_count = df2.groupby('Embarked')['Embarked'].count()
embarked_count
# Out:
# Embarked
# C    169
# Q     78
# S    644
# Name: Embarked, dtype: int64

# %%
sex_count = df2.groupby('Sex')['Survived'].sum()
sex_count
# Out:
# Sex
# female    230.0
# male      109.0
# Name: Survived, dtype: float64

# %%
sex_count = df2.groupby(['Pclass','Survived','Sex'])['Survived'].count()
sex_count
# Out:
# Pclass  Survived  Sex
# 1       0.0       female      5
#                   male       77
#         1.0       female     89
#                   male       45
# 2       0.0       female      6
#                   male       91
#         1.0       female     70
#                   male       17
# 3       0.0       female     73
#                   male      300
#         1.0       female     71
#                   male       47
# Name: Survived, dtype: int64

# %%
sex_count = df2.groupby(['Pclass'])['Survived'].sum()
sex_count
# Out:
# Pclass
# 1    134.0
# 2     87.0
# 3    118.0
# Name: Survived, dtype: float64

# %%
sex_count = df2.groupby(['Pclass'])['Survived'].count()
sex_count
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
per = df2.groupby(['Pclass'])['Survived'].sum() / df2.groupby(['Pclass'])['Survived'].count()*100
per
# Out:
# Pclass
# 1    62.037037
# 2    47.282609
# 3    24.032587
# Name: Survived, dtype: float64

# %%
per = df2.groupby(['Sex'])['Survived'].sum()/df2.groupby(['Sex'])['Survived'].count()*100
per
# Out:
# Sex
# female    73.248408
# male      18.890815
# Name: Survived, dtype: float64

# %%
sur = df2.groupby(['Embarked','Survived'])['Survived'].count()
sur
# Out:
# Embarked  Survived
# C         0.0          76
#           1.0          93
# Q         0.0          47
#           1.0          31
# S         0.0         429
#           1.0         215
# Name: Survived, dtype: int64
